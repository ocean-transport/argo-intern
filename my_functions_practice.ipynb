# %%
import my_stats as ms
import my_floats as mf

# %%
mf.float_plot(1902030)

# %%
a_float = mf.float_load(1902030)
a_float
# Out:
# <xarray.Dataset>
# Dimensions:                (N_PROF: 193, PRES_INTERPOLATED: 1500)
# Coordinates:
#   * N_PROF                 (N_PROF) int64 2 3 4 5 6 7 ... 197 201 205 209 213
#     LATITUDE               (N_PROF) float64 -36.95 -36.9 ... -32.53 -32.45
#     LONGITUDE              (N_PROF) float64 60.14 60.24 60.31 ... 33.63 31.48
#     TIME                   (N_PROF) datetime64[ns] 2016-11-30T16:16:52 ... 20...
#   * PRES_INTERPOLATED      (PRES_INTERPOLATED) int64 0 1 2 3 ... 1497 1498 1499
# Data variables:
#     CONFIG_MISSION_NUMBER  (N_PROF) int32 2 2 2 3 3 3 3 3 ... 7 7 11 11 11 11 11
#     CYCLE_NUMBER           (N_PROF) int32 2 3 4 5 6 7 ... 197 201 205 209 213
#     DATA_MODE              (N_PROF) <U1 'D' 'D' 'D' 'D' 'D' ... 'A' 'A' 'A' 'A'
#     DIRECTION              (N_PROF) <U1 'A' 'A' 'A' 'A' 'A' ... 'A' 'A' 'A' 'A'
#     PLATFORM_NUMBER        (N_PROF) int32 1902030 1902030 ... 1902030 1902030
# ...

# %%
ms.spectral_plot(a_float, 'N_PROF')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 ms.spectral_plot(a_float, 'N_PROF')
#
# File ~/argo-intern/my_stats.py:44, in spectral_plot(da, dim)
#      43 def spectral_plot(da, dim):
# ---> 44     da_spec = xrft.power_spectrum(da, dim=dim)
#      45     da_spec.plot()
#
# File ~/.conda/envs/argo/lib/python3.10/site-packages/xrft/xrft.py:723, in power_spectrum(da, dim, real_dim, scaling, window_correction, **kwargs)
#     717     warnings.warn(msg, FutureWarning)
#     719 kwargs.update(
#     720     {"true_amplitude": True, "true_phase": False}
#     721 )  # true_phase do not matter in power_spectrum
# --> 723 daft = fft(da, dim=dim, real_dim=real_dim, **kwargs)
#     724 updated_dims = [
#     725     d for d in daft.dims if (d not in da.dims and "segment" not in d)
#     726 ]  # Transformed dimensions
# ...
