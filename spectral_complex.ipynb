# %% [markdown]
# ## Simple Complex Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
points = 1000
x = np.arange(points)
#plt.figure(figsize=(10,7))

ys = []
amps = []
ks = []
ys_funct = 0
color_li = ['red', 'orange', 'yellow', 'green', 'blue', 'purple']

for n in range(0,6):
    amp = np.random.randint(1,15)
    k = np.random.randint(10,500)
    
    amps.append(amp)
    ks.append(k)
    y = np.sin(k*(x/points))*a
    ys.append(y)
    plt.subplot(4,2,n+3)
    plt.plot(x,y, color=color_li[n])
    
for y in ys:
    ys_funct =ys_funct + y
    
plt.subplot(4,2,1)
plt.plot(x,ys_funct, color='black')

plt.subplots_adjust(wspace=0.4, hspace=0.4)

# %%
for n in range(0,6):
    plt.plot(ks[n], amps[n], marker='o', color=color_li[n])

plt.title("Spectral Curve")
plt.xlabel("Wavenunmber")
plt.ylabel("Amplitude")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
#       1 for n in range(0,6):
# ----> 2     plt.plot(ks[n], amps[n], marker='o', color=color_li[n])
#       4 plt.title("Spectral Curve")
#       5 plt.xlabel("Wavenunmber")
#
# IndexError: list index out of range
