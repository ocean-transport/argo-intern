# %% [markdown]
# ## Argo File Loader

# %%
# try with newest snapshot
# try with ftp that gmaze used in issue, probably going to be really slow

# %%
import xarray as xr
import numpy as np
import gsw
import matplotlib.pyplot as plt
import matplotlib as mpl
from importlib import reload
from cmocean import cm as cmo
import xrft
import pandas as pd
import argopy
from argopy import DataFetcher
import dask

# %%
print('argopy: {}, xarray: {}, dask: {}'.format(argopy.__version__, xr.__version__, dask.__version__))

# %%
import os
os.chdir('/home.ufs/amf2288/argo-intern/funcs')
import density_funcs as df
import EV_funcs as ef
import filt_funcs as ff
import plot_funcs as pf
import processing_funcs as prf

# %%
reload(df)
reload(ef)
reload(ff)
reload(pf)
#reload(mf)
reload(prf)

# %% [markdown]
# ## testing parallel loading with dask client

# %%
from dask.distributed import Client

# %%
client= Client(processes=True)

# %%
print(client)

# %%
box = [-27.5, -22.5, -5, 5, 0, 2001]

# %%
# %%time
with argopy.set_options(parallel=client):
    f = DataFetcher(src='gdac', ftp='/swot/SUM05/dbalwada/Argo_sync', progress=True).region(box)
    print('%i chunks to process' % len(f.uri))
    print(f)
    ds = f.load().data#.to_xarray()

# %% [markdown]
# Okay the process is running on multiple GPUs, in this case 10-12 machines. However, obviously there are a ton of error messages---I'm not really sure what's going wrong. The box I've started with is really small, so I don't think there should be a memory error. Not sure where to go from here.

# %% [markdown]
# ## Load by box (coordinate: N_PROF)

# %%
#box=[lon_min,lon_max,lat_min,lat_max,depth_min,depth_max]
box_atl = [-25,-20,-70,70,0,2001]
box_pac = [-180,-175,-70,70,0,2001]
box_watl = [-60,-55,10,45,0,2001]
box_wpac = [150,155,-5,50,0,2001]
box_wind = [60,65,-65,25,0,2001]

# %%
NW = [-180,0,0,90,0,2001]
NE = [0,180,-90,0,0,2001]
SW = [-180,0,-90,0,0,2001]
SE = [0,-180,-90,0,0,2001]

# %%
box1 = [-180,-90,  0,90,0,2001]
box2 = [- 90,  0,  0,90,0,2001]
box3 = [   0, 90,  0,90,0,2001]
box4 = [  90,180,  0,90,0,2001]
box5 = [-180,-90,-90, 0,0,2001]
box6 = [- 90,  0,-90, 0,0,2001]
box7 = [   0, 90,-90, 0,0,2001]
box8 = [  90,180,-90, 0,0,2001]

# %%
#pf.plot_box([NW,NE,SW,SE])

# %%
ds = prf.get_box(box2,2)
# Out:
# loading points complete
# /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/data_fetchers/gdac_data.py:331: UserWarning: Found more than 50 files to load, this may take a while to process sequentially ! Consider using another data source (eg: 'erddap') or the 'parallel=True' option to improve processing time.
#   warnings.warn(
#  47%|████▋     | 1654/3548 [1:39:12<1:08:53,  2.18s/it]/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: RuntimeWarning: overflow encountered in multiply
#   return bound(*args, **kwds)
# 100%|██████████| 3548/3548 [3:40:34<00:00,  3.73s/it]
# Oops! <class 'numpy.core._exceptions._ArrayMemoryError'> occurred.
# Fail to cast: TEMP_QC
# Encountered unique values: [1. 2.]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ds = prf.get_box(box2,2)
#
# File /home/amf2288/argo-intern/funcs/processing_funcs.py:56, in get_box(box, interp_step)
#      53 ds = argo_loader.region(box)
#      54 print("loading points complete")
# ---> 56 ds = ds.to_xarray()
#      57 print("to xarray complete")
#      59 ds = ds.argo.teos10(["CT", "SA", "SIG0"])
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/fetchers.py:617, in ArgoDataFetcher.to_xarray(self, **kwargs)
#     612     raise InvalidFetcher(
#     613         " Initialize an access point (%s) first."
#     614         % ",".join(self.Fetchers.keys())
#     615     )
#     616 xds = self.fetcher.to_xarray(**kwargs)
# --> 617 xds = self.postprocess(xds)
#     619 return xds
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/fetchers.py:373, in ArgoDataFetcher.postprocess(self, *args, **kwargs)
#     372 def postprocess(self, *args, **kwargs):
# --> 373     return self._pp_workflow(*args, **kwargs)
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/fetchers.py:383, in ArgoDataFetcher.define_postprocessor.<locals>.workflow(xds)
#     381 def workflow(xds):
#     382     xds = self.fetcher.transform_data_mode(xds)
# --> 383     xds = self.fetcher.filter_qc(xds, QC_list=[1, 2])
#     384     xds = self.fetcher.filter_variables(xds)
#     385     return xds
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/data_fetchers/gdac_data.py:432, in GDACArgoDataFetcher.filter_qc(self, ds, **kwargs)
#     431 def filter_qc(self, ds: xr.Dataset, **kwargs):
# --> 432     ds = ds.argo.filter_qc(**kwargs)
#     433     if ds.argo._type == "point":
#     434         ds["N_POINTS"] = np.arange(0, len(ds["N_POINTS"]))
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/xarray.py:724, in ArgoAccessor.filter_qc(self, QC_list, QC_fields, drop, mode, mask)
#     721     this_mask = this_mask >= 1  # any
#     723 if not mask:
# --> 724     this = this.argo._where(this_mask, drop=drop)
#     725     this.argo.add_history(
#     726         "[%s] filtered to retain points with QC in [%s]"
#     727         % (
#    (...)
#     730         )
#     731     )
#     732     if this.argo.N_POINTS == 0:
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/xarray.py:223, in ArgoAccessor._where(self, cond, other, drop)
#     221 this = self._obj.copy(deep=True)
#     222 this = this.where(cond, other=other, drop=drop)
# --> 223 this = this.argo.cast_types()
#     224 # this.argo.add_history("Modified with 'where' statement")
#     225 return this
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/xarray.py:230, in ArgoAccessor.cast_types(self, **kwargs)
#     228 """Make sure variables are of the appropriate types according to Argo"""
#     229 ds = self._obj
# --> 230 return cast_Argo_variable_type(ds, **kwargs)
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/utils/casting.py:181, in cast_Argo_variable_type(ds, overwrite)
#     179 if overwrite or ("casted" in ds[v].attrs and ds[v].attrs["casted"] == 0):
#     180     try:
# --> 181         ds[v] = cast_this_da(ds[v], v)
#     182     except Exception:
#     183         print("Oops!", sys.exc_info()[0], "occurred.")
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/utils/casting.py:132, in cast_Argo_variable_type.<locals>.cast_this_da(da, v)
#     129 # Address weird string values:
#     130 # (replace missing or nan values by a '0' that will be cast as an integer later
#     131 if da.dtype == float:
# --> 132     val = da.astype(str).values
#     133     val[np.where(val == "nan")] = "0"
#     134     da.values = val
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/xarray/core/common.py:1475, in DataWithCoords.astype(self, dtype, order, casting, subok, copy, keep_attrs)
#    1472 kwargs = dict(order=order, casting=casting, subok=subok, copy=copy)
#    1473 kwargs = {k: v for k, v in kwargs.items() if v is not None}
# -> 1475 return apply_ufunc(
#    1476     duck_array_ops.astype,
#    1477     self,
#    1478     dtype,
#    1479     kwargs=kwargs,
#    1480     keep_attrs=keep_attrs,
#    1481     dask="allowed",
#    1482 )
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/xarray/core/computation.py:1270, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1268 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1269 elif any(isinstance(a, DataArray) for a in args):
# -> 1270     return apply_dataarray_vfunc(
#    1271         variables_vfunc,
#    1272         *args,
#    1273         signature=signature,
#    1274         join=join,
#    1275         exclude_dims=exclude_dims,
#    1276         keep_attrs=keep_attrs,
#    1277     )
#    1278 # feed Variables directly through apply_variable_ufunc
#    1279 elif any(isinstance(a, Variable) for a in args):
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/xarray/core/computation.py:316, in apply_dataarray_vfunc(func, signature, join, exclude_dims, keep_attrs, *args)
#     311 result_coords, result_indexes = build_output_coords_and_indexes(
#     312     args, signature, exclude_dims, combine_attrs=keep_attrs
#     313 )
#     315 data_vars = [getattr(a, "variable", a) for a in args]
# --> 316 result_var = func(*data_vars)
#     318 out: tuple[DataArray, ...] | DataArray
#     319 if signature.num_outputs > 1:
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/xarray/core/computation.py:825, in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     820     if vectorize:
#     821         func = _vectorize(
#     822             func, signature, output_dtypes=output_dtypes, exclude_dims=exclude_dims
#     823         )
# --> 825 result_data = func(*input_data)
#     827 if signature.num_outputs == 1:
#     828     result_data = (result_data,)
#
# File ~/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/xarray/core/duck_array_ops.py:215, in astype(data, dtype, **kwargs)
#     213         return data.astype(dtype, **kwargs)
#     214     return xp.astype(data, dtype, **kwargs)
# --> 215 return data.astype(dtype, **kwargs)
#
# MemoryError: Unable to allocate 16.7 GiB for an array with shape (140411734,) and data type <U32

# %%
ds

# %%
ds = ds.assign_attrs({"Fetched_uri":''})
ds

# %%
ds.to_netcdf("/swot/SUM05/amf2288/sync-boxes/lon:({},{})_lat:({},{})_ds_z.nc".format(NW[0],NW[1],NW[2],NW[3]))

# %%
box_1x = [-10,0,-10,0,0,2000]   #error
box_1y = [-10,0,-20,-10,0,2000] #done
box_1z = [-10,0,-30,-20,0,2000] #done
box_1a = [-10,0,-40,-30,0,2000] #done
box_1b = [-10,0,-50,-40,0,2000] #done
box_1c = [-10,0,-60,-50,0,2000] #done
box_1d = [-10,0,-70,-60,0,2000] #done
box_long=[-10,-8,-70,-10,0,2000]

# %%
pf.plot_box([box_1x,box_1y,box_1z,box_1a,box_1b,box_1c,box_1d,box_long])

# %%
ds_z=ff.get_box(box_long,4)

# %%
ds['N_PROF'].attrs = {'name':'Fetched Profile Number'}
ds['PRES_INTERPOLATED'].attrs = {'name':'Interpolated Pressure', 'units':'dbar', 'notes':'interpolated to standard pressure grid of 2m'}

ds['N_PROF_NEW'].attrs = {'name':'Sequential Profile Number'}
ds['LATITUDE'].attrs = {'name':'Latitude', 'units':'°N'}
ds['LONGITUDE'].attrs = {'name':'Longitude', 'units':'°E'}
ds['month'].attrs = {'name':'Month'}
ds['year'].attrs = {'name':'Year'}
ds['MLD'].attrs = {'name':'Mixed Layer Depth', 'units':'m'}

ds['CT'].attrs = {'name':'Conservative Temperature', 'units':'°C'}
ds['SA'].attrs = {'name':'Absolute Salinity', 'units':'g kg-1'}
ds['SIG0'].attrs = {'name':'Potential Density', 'units':'kg m-1', 'notes':'referenced to 0 dbar'}
ds['SPICE'].attrs = {'name':'Spiciness', 'units':'kg m-1', 'notes':'referenced to 0 dbar'}                  
ds = ds.assign_attrs({"Fetched_uri":''})

# %%
ds_z

# %%
plt.scatter(ds_z.LONGITUDE, ds_z.LATITUDE)

# %%
ds_z.to_netcdf("202206_boxes/lon:({},{})_lat:({},{})_ds_z.nc".format(box_long[0],box_long[1],box_long[2],box_long[3]))

# %%
erddap_loader=ArgoDataFetcher(src'erddap',parallel=True,progress=True)

# %%
gmaze_loader=ArgoDataFetcher(src='gdac',ftp='https://data-argo.ifremer.fr/',parallel=True,progress=True)

# %%
usa_loader=ArgoDataFetcher(src='gdac',ftp='ftp://usgodae.org/pub/outgoing/argo',parallel=True,progress=True)

# %%
ds=argo_loader.region(box_1x)
print('loading points complete')
ds=ds.to_xarray()
print('to xarray complete')

# %%
ds=ds.argo.teos10(['CT','SA','SIG0'])
ds=ds.argo.point2profile()
print('point to profile complete')

# %%
def test_get_box(box,sample_min):
    '''Takes latitude/longitude/depth data and a sample rate and returns an xarray with CT, SA, SIG0, and SPICE interpolated to a pressure grid of 2m. 
    
    box: lat/lon in the form: box=[lon_min, lon_max, lat_min, lat_max, depth_min, depth_max]
    sample_min: minimum sample rate [m]
    '''
    
    ds=argo_loader.region(box)
    print('loading points complete')
    
    ds=ds.to_xarray()
    print('to xarray complete')
    
    ds=ds.argo.teos10(['CT','SA','SIG0'])
    ds=ds.argo.point2profile()
    print('point to profile complete')
    
    ds_interp=get_ds_interp(ds,0,2000,sample_min)
    print('interpolation complete')
    
    ds_interp['SPICE'] = gsw.spiciness0(ds_interp.SA,ds_interp.CT).rename('SPICE')
    print('adding spice complete')
        
    return ds_interp

# %%
test = test_get_box(box_medi,4)

# %%
ds=argo_loader.region(box_medi)

# %%
ds = ds.data

# %%
ds

# %%
ds.PSAL.dropna('N_POINTS')

# %%
for n in range(0,len(ds.N_PROF)):

# %%
'''
methods are also functions, but specific to the class they're applied to
class (animals) --> subclass (dogs) --> object (golden retriever)
open_mfdataset() from xarray, for opening data in multiple netcdfs
1) write loop opening all files yourself, check for PSAL, if not there remove file
2) go into open_mfdataset() and see if there's a loop there to exploit instead

locally install repo (pip install -e??)
uses the code from the local repo instead
then make changes to repo: print statement in part of the code we think is happening
then work on loops, etc.


'''

# %%
def to_xarray(self, errors: str = "ignore"):
        """ Load Argo data and return a :class:`xarray.Dataset`

        Parameters
        ----------
        errors: str, default='ignore'
            Define how to handle errors raised during data URIs fetching:

                - 'ignore' (default): Do not stop processing, simply issue a debug message in logging console
                - 'silent':  Do not stop processing and do not issue log message
                - 'raise': Raise any error encountered

        Returns
        -------
        :class:`xarray.Dataset`
        """
        if (
            len(self.uri) > 50
            and isinstance(self.method, str)
            and self.method == "sequential"
        ):
            warnings.warn(
                "Found more than 50 files to load, this may take a while to process sequentially ! "
                "Consider using another data source (eg: 'erddap') or the 'parallel=True' option to improve processing time."
            )
        elif len(self.uri) == 0:
            raise DataNotFound("No data found for: %s" % self.indexfs.cname)

        # Download data:
        ds = self.fs.open_mfdataset(
            self.uri, #list of all float files?
            method=self.method,
            concat_dim="N_POINTS",
            concat=True,
            preprocess=self._preprocess_multiprof,
            progress=self.progress,
            errors=errors,
            open_dataset_opts={'xr_opts': {'decode_cf': 1, 'use_cftime': 0, 'mask_and_scale': 1}},
        )

        # Data post-processing:
        ds["N_POINTS"] = np.arange(
            0, len(ds["N_POINTS"])
        )  # Re-index to avoid duplicate values
        ds = ds.set_coords("N_POINTS")
        ds = ds.sortby("TIME")

        # Remove netcdf file attributes and replace them with simplified argopy ones:
        ds.attrs = {}
        if self.dataset_id == "phy":
            ds.attrs["DATA_ID"] = "ARGO"
        if self.dataset_id == "bgc":
            ds.attrs["DATA_ID"] = "ARGO-BGC"
        ds.attrs["DOI"] = "http://doi.org/10.17882/42182"
        ds.attrs["Fetched_from"] = self.server
        ds.attrs["Fetched_by"] = getpass.getuser()
        ds.attrs["Fetched_date"] = pd.to_datetime("now", utc=True).strftime("%Y/%m/%d")
        ds.attrs["Fetched_constraints"] = self.cname()
        if len(self.uri) == 1:
            ds.attrs["Fetched_uri"] = self.uri[0]
        else:
            ds.attrs["Fetched_uri"] = ";".join(self.uri)

        return ds

# %%
print(ds_z.SIG0.values.min(), ds_z.SIG0.values.max())

# %%
rho_grid = np.linspace(26.6, 28, 1001)

# %%
ds_rho = df.interpolate2density_prof(ds_z, rho_grid)

# %%
ds_rho

# %%
ds_rho.to_netcdf("202206_boxes/lon:({},{})_lat:({},{})_ds_rho.nc".format(box[0],box[1],box[2],box[3]))

# %% [markdown]
# ## Load by float (coordinate: distance)

# %%
float_ID = 6901265

# %%
ds_z = ff.get_float(float_ID, 4)

# %%
ds_z = ds_z.assign_attrs({"Fetched_uri":''})

# %%
ds_z

# %%
ds_z.to_netcdf("202206_floats/float_ID:({})_ds_z.nc".format(float_ID))

# %%
print(ds_z.SIG0.values.min(), ds_z.SIG0.values.max())

# %%
rho_grid = np.linspace(26.4, 28, 1001)

# %%
ds_rho = df.interpolate2density_prof(ds_z, rho_grid)

# %%
ds_rho

# %%
ds_rho.to_netcdf("202206_floats/float_ID:({})_ds_rho.nc".format(float_ID))

# %% [markdown]
# ## Loading Boxes by Degree

# %%
lons = np.arange(-180,181,4)
lats = np.arange(-90,91,4)

boxes=[]

for n in range(0,len(lons)-1):
    for m in range(0,len(lats-1)):
        lon_min = lons[n]
        lon_max = lons[n+1]
        lat_min = lats[n]
        lat_max = lats[n+1]
        box_n = np.array([lon_min, lon_max, lat_min, lat_max])
        boxes.append(box_n)

# %%
n=0
lons[n+1]

# %%
from argopy import IndexFetcher as ArgoIndexFetcher

box_bad=[-15,-14,36.5,37]#, '2000-01-01', '2021-06'] # need to remove pressure poinds because the region function for this index fetcher seems a bit different.

idx = ArgoIndexFetcher(src='gdac',dataset='phy',mode='standard',
                            ftp="/swot/SUM05/dbalwada/202203-ArgoData").region(box_bad).load()
idx.index

# %%
float_IDs = [1900041,1900749,]
