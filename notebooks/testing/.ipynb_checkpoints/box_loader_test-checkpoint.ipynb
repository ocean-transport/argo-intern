# %% [markdown]
# # Box Loader Testing

# %% [markdown]
# I need to test a few things about the steps in the `argo_box_loader` notebook. There are a few things that might make a difference by decreasing the size of an array, but I want to try here on a box that takes a lot less time to load.

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import argopy
import scipy.ndimage as filter
import scipy
import matplotlib
import gsw
import traceback
from importlib import reload

import argopy
from argopy import DataFetcher as ArgoDataFetcher

argo_loader = ArgoDataFetcher(
    src="gdac", ftp="/swot/SUM05/dbalwada/Argo_sync", progress=True
)

# %%
import os
import sys
os.chdir('/home.ufs/amf2288/argo-intern/funcs')
sys.path.append(os.path.abspath('../funcs'))

import processing_funcs as prf

# %%
import dask
from dask.distributed import Client, LocalCluster

# Create a LocalCluster
cluster = LocalCluster(n_workers=32, threads_per_worker=2, memory_limit='30GiB')

# Connect to the cluster
client = Client(cluster)

# Print the cluster information
print(cluster)
# Out:
# LocalCluster(566e9a36, 'tcp://127.0.0.1:42364', workers=32, threads=64, memory=0.94 TiB)
# Task exception was never retrieved
# future: <Task finished name='Task-19624' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19633' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19596' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19640' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19605' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19648' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19616' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19578' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19626' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19588' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19607' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19618' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19580' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19628' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19590' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19657' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19665' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19609' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19573' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19620' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19582' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19592' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19659' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19602' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19611' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19575' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19643' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19584' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19594' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19661' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19669' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19576' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19644' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19585' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19653' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19662' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19670' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19638' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19577' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19645' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19623' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19663' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19615' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19656' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19625' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19587' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19641' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19606' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19617' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19579' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19627' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19589' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19599' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19608' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19572' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19619' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19629' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19591' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19601' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19666' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19610' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19583' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19651' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19593' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19660' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19603' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19668' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19612' coro=<Client._gather.<locals>.wait() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# 2025-03-11 01:00:53,852 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35375' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'get_box_delayed-5b4a4c71-94e5-4f3f-a408-51d1d74838f7', 'get_box_delayed-87413045-4676-4ee8-b41f-c615e77995c7', 'get_box_delayed-426845cd-0654-4727-b474-85b314678caf', 'get_box_delayed-4493c10f-486d-4c1b-8df5-d5254dc71241', 'get_box_delayed-05f41d6c-d793-4902-b032-083f67f1b53d', 'get_box_delayed-e0b62295-abee-4005-8ebe-af0fd1941fb8'} (stimulus_id='handle-worker-cleanup-1741669253.8519204')
# 2025-03-11 01:00:53,859 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42248' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'get_box_delayed-ad22c1db-1292-4ca6-b7b5-022accf307f2'} (stimulus_id='handle-worker-cleanup-1741669253.8589666')
# 2025-03-11 01:00:53,862 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40488' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'get_box_delayed-24b8b0b3-c906-43a0-b89a-5757890783ff', 'get_box_delayed-6ad28a0d-76cb-4856-b063-10e60956919c', 'get_box_delayed-b93f7ef4-9d1f-42d4-8610-e98be20d10f9'} (stimulus_id='handle-worker-cleanup-1741669253.8623455')
# 2025-03-11 01:00:53,866 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38280' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {
# 2025-03-11 01:00:55,699 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:55,706 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:55,713 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:55,772 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:55,865 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:55,886 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:55,895 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:55,911 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:55,984 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:55,988 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:56,006 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:56,034 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:56,044 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:56,046 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:56,191 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:56,204 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:56,228 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:56,337 - distributed.nanny - WARNING - Restarting worker
# 2025-03-11 01:00:56,710 - distributed.nanny - WARNING - Restarting worker

# %%
@dask.delayed
def get_box_delayed(*args, **kwargs):
    try:
        return prf.get_box(*args, **kwargs)
    except Exception as e:
        return type(e).__name__, str(e)

def get_box_dask(boxes_list):
    
    boxes_list = [tuple([box]) for box in boxes_list]
    
    # Create a list of delayed tasks
    tasks = [get_box_delayed(*args) for args in boxes_list]

    # Compute the results in parallel
    results = dask.compute(*tasks)
    
    errors=[]

    # Process the results as needed
    for n, result in enumerate(results):
        if isinstance(result, tuple) and isinstance(result[0], str):
            error_type, error_message = result
            print("Error in box {}: {} - {}".format([boxes_list[n][0][0],boxes_list[n][0][1],boxes_list[n][0][2],boxes_list[n][0][3]], error_type, error_message))
            errors.append([boxes_list[n][0][0],boxes_list[n][0][1],boxes_list[n][0][2],boxes_list[n][0][3], error_type, error_message])
        else:
            result.to_netcdf("/swot/SUM05/amf2288/sync-boxes/new_test/lon:({},{})_lat:({},{})_ds_z.nc".format(boxes_list[n][0][0],boxes_list[n][0][1],boxes_list[n][0][2],boxes_list[n][0][3]))
            print("Saved box {} of {}".format(n+1, len(results)))
            
    return errors

# %%
from typing import List, Tuple

#def generate_grid(min_lat: float, max_lat: float, min_lon: float, max_lon: float, step: float) -> List[Tuple[float, float, float, float]]:
def generate_grid(box, step):
    grid = []
    lon_min, lon_max, lat_min, lat_max = box[0],box[1],box[2],box[3]
    lat = lat_min
    while lat < lat_max:
        lon = lon_min
        while lon < lon_max:
            # Ensure the box does not exceed the specified bounds
            box_lat_max = min(lat + step, lat_max)
            box_lon_max = min(lon + step, lon_max)
            box = [lat, box_lat_max, lon, box_lon_max, box[4], box[5]]
            grid.append(box)
            lon += step
        lat += step
    return grid

# %%
def get_target_area(area, region_step, target_step):
    
    regions = generate_grid(area, region_step)
    print('-' * 50)
    print("Cluster: {}".format(cluster))
    print('-' * 50)
    print("THE REGIONS ARE {}".format(regions))
    print('-' * 50)
    
    errors_list = []
    
    for n,region in enumerate(regions):
        boxes = generate_grid(region, target_step)
        print('-' * 50)
        print("REGION #{} OUT OF {} IS: {}".format(n+1, len(regions), region))
        print('-' * 50)
        print("THE BOXES IN REGION #{} ARE {}".format(n+1,boxes))
        print('-' * 50)

        errors = get_box_dask(boxes)
        errors_list.append([errors])
        
        print('-' * 50)
        print("COMPLETED REGION #{} OUT OF {}".format(n+1,len(regions)))
        print('-' * 50)
        
    return errors_list

# %%
atl1 = [-75,25,-90,0,0,2000]
atl2 = [-75,25,0,90,0,2000]
ind1 = [25,120,-90,30,0,2000]
pac1 = [120,180,-90,0,0,2000]
pac2 = [120,180,0,90,0,2000]
pac3 = [-180,-75,-90,0,0,2000]
pac4 = [-180,-75,0,90,0,2000]

# %%
globe = [-180, 180, -90, 90, 0, 2002]

# %%
problem = [-130,-75,-90,10,0,2002]

problem1 = [-125,-75,-25,25,0,2000]
problem2 = [-125,-75,-75,-25,0,2000]
problem3 = [-175,-125,-25,25,0,2000]
problem4 = [-175,-125,-75,-25,0,2000]

# %% [markdown]
# Need to rerun boxes[2]!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
area = globe
region_step = 50
box_step = 5
interp_step = 2
get_target_area(area, region_step, box_step)
# Out:
# --------------------------------------------------
# Cluster: LocalCluster(566e9a36, 'tcp://127.0.0.1:42364', workers=32, threads=64, memory=0.94 TiB)
# --------------------------------------------------
# THE REGIONS ARE [[-90, -40, -180, -130, 0, 2002], [-90, -40, -130, -80, 0, 2002], [-90, -40, -80, -30, 0, 2002], [-90, -40, -30, 20, 0, 2002], [-90, -40, 20, 70, 0, 2002], [-90, -40, 70, 120, 0, 2002], [-90, -40, 120, 170, 0, 2002], [-90, -40, 170, 180, 0, 2002], [-40, 10, -180, -130, 0, 2002], [-40, 10, -130, -80, 0, 2002], [-40, 10, -80, -30, 0, 2002], [-40, 10, -30, 20, 0, 2002], [-40, 10, 20, 70, 0, 2002], [-40, 10, 70, 120, 0, 2002], [-40, 10, 120, 170, 0, 2002], [-40, 10, 170, 180, 0, 2002], [10, 60, -180, -130, 0, 2002], [10, 60, -130, -80, 0, 2002], [10, 60, -80, -30, 0, 2002], [10, 60, -30, 20, 0, 2002], [10, 60, 20, 70, 0, 2002], [10, 60, 70, 120, 0, 2002], [10, 60, 120, 170, 0, 2002], [10, 60, 170, 180, 0, 2002], [60, 90, -180, -130, 0, 2002], [60, 90, -130, -80, 0, 2002], [60, 90, -80, -30, 0, 2002], [60, 90, -30, 20, 0, 2002], [60, 90, 20, 70, 0, 2002], [60, 90, 70, 120, 0, 2002], [60, 90, 120, 170, 0, 2002], [60, 90, 170, 180, 0, 2002]]
85, -80, 0, 2002], [-150, -145, -80, -75, 0, 2002], [-150, -145, -75, -70, 0, 2002], [-150, -145, -70, -65, 0, 2002], [-150, -145, -65, -60, 0, 2002], [-150, -145, -60, -55, 0, 2002], [-150, -145, -55, -50, 0, 2002], [-150, -145, -50, -45, 0, 2002], [-150, -145, -45, -40, 0, 2002], [-145, -140, -90, -85, 0, 2002], [-145, -140, -85, -80, 0, 2002], [-145, -140, -80, -75, 0, 2002], [-145, -140, -75, -70, 0, 2002], [-145, -140, -70, -65, 0, 2002], [-145, -140, -65, -60, 0, 2002], [-145, -140, -60, -55, 0, 2002], [-145, -140, -55, -50, 0, 2002], [-145, -140, -50, -45, 0, 2002], [-145, -140, -45, -40, 0, 2002], [-140, -135, -90, -85, 0, 2002], [-140, -135, -85, -80, 0, 2002], [-140, -135, -80, -75, 0, 2002], [-140, -135, -75, -70, 0, 2002], [-140, -135, -70, -65, 0, 2002], [-140, -135, -65, -60, 0, 2002], [-140, -135, -60, -55, 0, 2002], [-140, -135, -55, -50, 0, 2002], [-140, -135, -50, -45, 0, 2002], [-140, -135, -45, -40, 0, 2002], [-135, -130, -90, -85, 0, 2002], [-135, -130, -85, -80, 0, 2002], [-135, -130, -80, -75, 0, 2002], [-135, -130, -75, -70, 0, 2002], [-135, -130, -70, -65, 0, 2002], [-135, -130, -65, -60, 0, 2002], [-135, -130, -60, -55, 0, 2002], [-135, -130, -55, -50, 0, 2002], [-135, -130, -50, -45, 0, 2002], [-135, -130, -45, -40, 0, 2002]]
# --------------------------------------------------
# KeyboardInterrupt
#
# 2025-03-11 01:00:53,747 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/runners.py", line 195, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/base_events.py", line 678, in run_until_complete
#     self.run_forever()
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/base_events.py", line 1961, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-03-11 01:00:53,749 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('get_box_delayed-109cf96c-1861-411d-b975-8a424025868b')" coro=<Worker.execute() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-03-11 01:00:53,749 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('get_box_delayed-62392808-7f4a-40b1-9345-f3f886a239b6')" coro=<Worker.execute() done, defined at /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/worker_state_machine.py:3607>> ended with CancelledError
# 2025-03-11 01:00:53,753 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/comm/tcp.py", line 227, in read
#     (frames_nosplit_nbytes,) = struct.unpack(fmt, frames_nosplit_nbytes_bin)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# 2025-03-11 01:00:53,752 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/runners.py", line 195, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/base_events.py", line 678, in run_until_complete
#     self.run_forever()
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/tornado/ioloop.py", line 759, in _run_callback
#     ret = gen.convert_yielded(ret)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/functools.py", line 912, in wrapper
#     return dispatch(args[0].__class__)(*args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/tornado/gen.py", line 881, in convert_yielded
#     return _wrap_awaitable(yielded)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/tornado/gen.py", line 847, in _wrap_awaitable
#     fut = asyncio.ensure_future(awaitable)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/tasks.py", line 695, in ensure_future
#     return loop.create_task(coro_or_future)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/base_events.py", line 457, in create_task
#     task = tasks.Task(coro, loop=self, name=name, context=context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/base_events.py", line 803, in call_soon
#     handle = self._call_soon(callback, args, context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/base_events.py", line 819, in _call_soon
#     handle = events.Handle(callback, args, self, context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/events.py", line 36, in __init__
#     def __init__(self, callback, args, loop, context=None):
#
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Feb_25/lib/python3.12/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^

# %%
# Shut down the client
client.close()

# Shut down the cluster
cluster.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Shut down the client
# ----> 2 client.close()
#       4 # Shut down the cluster
#       5 cluster.close()
#
# NameError: name 'client' is not defined

# %% [markdown]
# # Data Loading Issues

# %%
ds = xr.open_dataset('/swot/SUM05/amf2288/sync-boxes/test_error.nc')

# %%
fig = plt.figure(figsize=(5, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)

ax.scatter(ds.LONGITUDE,ds.LATITUDE,transform=ccrs.PlateCarree(),color='tab:blue',s=1)
