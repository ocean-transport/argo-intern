# %% [markdown]
# # Smoothing Options Comparison

# %% [markdown]
# In this notebook, I will be comparing how multiple different ways to separate the mean-scale shape of a profile from smaller pertubations. These methods include:
# - polynomial fit
# - filtering
# - averaging
#
# I'm selecting a region near the Irminger Sea to compare with Figures 3 and 5 of Castro 2024. Look at both profiles of the tracer and the vertical gradient of the tracer

# %%
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.path import Path
import seaborn as sns
import seaborn
import pandas as pd
import numpy as np
from importlib import reload
import cartopy.crs as ccrs
import cmocean.cm as cmo
import gsw
import scipy.ndimage as filter

# %%
import os
os.chdir('/home.ufs/amf2288/argo-intern/funcs')
import processing_funcs as prf
import filt_funcs as ff

# %% [markdown]
# ### Get Irms box

# %%
irms_box = [-45,-25,55,70,0,2001]
ds = prf.get_box(irms_box,2)
# Out:
# loading points complete
# /home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/argopy/data_fetchers/gdac_data.py:331: UserWarning: Found more than 50 files to load, this may take a while to process sequentially ! Consider using another data source (eg: 'erddap') or the 'parallel=True' option to improve processing time.
#   warnings.warn(
#  96%|█████████▌| 454/475 [20:14<00:58,  2.79s/it]/home.ufs/amf2288/mambaforge-pypy3/envs/Argo_Nov_24/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: RuntimeWarning: overflow encountered in multiply
#   return bound(*args, **kwds)
# 100%|██████████| 475/475 [21:21<00:00,  2.70s/it]
# to xarray complete
# point to profile complete
# interpolation complete
# adding spice complete
# adding MLD complete

# %%
ds
# Out:
# <xarray.Dataset> Size: 74MB
# Dimensions:            (N_PROF: 1535, PRES_INTERPOLATED: 1001)
# Coordinates:
#     TIME               (N_PROF) datetime64[ns] 12kB 2002-06-19T05:12:00 ... 2...
#     LATITUDE           (N_PROF) float64 12kB 55.8 57.31 56.98 ... 55.04 55.08
#     LONGITUDE          (N_PROF) float64 12kB -31.82 -44.65 ... -44.35 -43.1
#   * PRES_INTERPOLATED  (PRES_INTERPOLATED) int64 8kB 0 2 4 6 ... 1996 1998 2000
#   * N_PROF             (N_PROF) int64 12kB 8381 1343 8961 ... 4457 4458 4459
#     N_PROF_NEW         (N_PROF) int64 12kB 0 1 2 3 4 ... 1531 1532 1533 1534
#     MLD                (N_PROF) int64 12kB 28 384 56 112 466 ... 8 22 4 30 54
#     month_frac         (N_PROF) float64 12kB 6.641 3.861 9.64 ... 9.555 11.17
#     year_frac          (N_PROF) float64 12kB 2.003e+03 2.004e+03 ... 2.025e+03
# Data variables:
#     CT                 (N_PROF, PRES_INTERPOLATED) float64 12MB 9.409 ... 3.159
#     CYCLE_NUMBER       (N_PROF) int64 12kB 1 63 9 8 16 ... 299 110 304 305 310
#     DATA_MODE          (N_PROF) <U1 6kB 'D' 'D' 'D' 'D' 'D' ... 'A' 'R' 'R' 'R'
#     DIRECTION          (N_PROF) <U1 6kB 'A' 'A' 'A' 'A' 'A' ... 'A' 'A' 'A' 'A'
#     PLATFORM_NUMBER    (N_PROF) int64 12kB 6900175 4900101 ... 4902119 4902119
#     PRES               (N_PROF, PRES_INTERPOLATED) float32 6MB 15.0 ... 2e+03
#     PSAL               (N_PROF, PRES_INTERPOLATED) float32 6MB 34.95 ... 34.94
#     SA                 (N_PROF, PRES_INTERPOLATED) float64 12MB 35.12 ... 35.11
#     SIG0               (N_PROF, PRES_INTERPOLATED) float64 12MB 27.02 ... 27.82
#     TEMP               (N_PROF, PRES_INTERPOLATED) float32 6MB 9.42 ... 3.32
#     sample_rate        (N_PROF, PRES_INTERPOLATED) float32 6MB 10.0 10.0 ... 2.0
#     SPICE              (N_PROF, PRES_INTERPOLATED) float64 12MB 1.119 ... 0.2233
# Attributes:
#     raw_attrs:            {'raw_attrs': {'title': 'Argo float vertical profil...
#     DATA_ID:              ARGO
#     DOI:                  http://doi.org/10.17882/42182
#     Fetched_from:         https://data-argo.ifremer.fr
#     Fetched_by:           amf2288
#     Fetched_date:         2024/11/11
#     Fetched_constraints:  [x=-45.00/-25.00; y=55.00/70.00; z=0.0/2001.0]
#     Fetched_uri:          https://data-argo.ifremer.fr/dac/coriolis/6900242/6...
#     Processing_history:   [PRES,TEMP,PSAL] real-time and adjusted/delayed var...

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines()
ax.set_extent([-50,0,40,70])
ax.gridlines(draw_labels=True)

ax.scatter(ds.LONGITUDE,ds.LATITUDE,transform=ccrs.PlateCarree(),color='tab:blue',label='Section 1: Western North Atlantic',s=1)

# %% [markdown]
# ### Apply Smoothing Methods

# %%
n=32
var='SA'
prof = ds.isel(N_PROF=n)[var]

# %%
#polynomial fit
coeff = np.polyfit(prof.PRES_INTERPOLATED.values, prof, 3)
polynomial = np.poly1d(coeff)
poly = polynomial(ds.PRES_INTERPOLATED.values)

# %%
#filtering
lfilter=200
nfilter = ff.get_nfilter(ds, lfilter)
filt = filter.gaussian_filter1d(prof,sigma=nfilter,mode='nearest')

# %%
#spatial averaging
lat_min,lat_max,lon_min,lon_max = prof.LATITUDE-2,prof.LATITUDE+2,prof.LONGITUDE-2,prof.LONGITUDE+2 
ds_box = ds.where((ds.LATITUDE >= lat_min) & (ds.LATITUDE <= lat_max) & (ds.LONGITUDE >= lon_min) & (ds.LONGITUDE <= lon_max), drop=True)
spav = ds_box[var].mean('N_PROF')

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines()
ax.set_extent([-45,-25,55,65])
ax.gridlines(draw_labels=True)

ax.scatter(ds.LONGITUDE,ds.LATITUDE,transform=ccrs.PlateCarree(),color='tab:blue',s=10)
ax.scatter(prof.LONGITUDE,prof.LATITUDE,transform=ccrs.PlateCarree(),color='tab:red',s=100)
ax.scatter(ds_box.LONGITUDE,ds_box.LATITUDE,transform=ccrs.PlateCarree(),color='k',s=10)

# %% [markdown]
# ### Compare Profiles

# %%
plt.figure(figsize=(5,10))

plt.plot(prof.values, prof.PRES_INTERPOLATED.values, color='k', linestyle='--', label='profile')
plt.plot(poly, prof.PRES_INTERPOLATED.values, label='polynomial fit, 4th order')
plt.plot(filt, prof.PRES_INTERPOLATED.values, label='filtering, l=100m')
plt.plot(spav, prof.PRES_INTERPOLATED.values, label='average across 5x5 box')
#plt.gca().invert_yaxis()
plt.ylim(2000,0)
plt.legend()

# %% [markdown]
# ### Compare Vertical Derivatives
