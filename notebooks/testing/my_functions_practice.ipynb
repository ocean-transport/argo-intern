# %%
import my_stats as ms
import my_floats as mf
import xrft
import xarray as xr
import matplotlib as plt
import scipy
import numpy as np

# %%
mf.float_plot(1902030)

# %%
afloat = mf.float_load(1902030)
TEMP_afloat = afloat.TEMP
SAL_afloat = afloat.PSAL

# %%
TEMP_spec = xrft.power_spectrum(TEMP_afloat.dropna('N_PROF')-TEMP_afloat.mean('N_PROF'), dim='PRES_INTERPOLATED')
#TEMP_spec
TEMP_spec.mean('N_PROF').plot(xlim=(-0.1,0.1))

# %%
points = TEMP_afloat.shape[1]
x=np.linspace(0,100,points)
win_gaus = scipy.signal.windows.gaussian(points,std=4)
filt_gaus = scipy.signal.convolve(TEMP_afloat[1], win_gaus, mode='same')
plt.plot(x,filt_gaus)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [77], in <cell line: 5>()
#       3 win_gaus = scipy.signal.windows.gaussian(points,std=4)
#       4 filt_gaus = scipy.signal.convolve(TEMP_afloat[1], win_gaus, mode='same')
# ----> 5 plt.plot(x,filt_gaus)
#
# File ~/.conda/envs/argo/lib/python3.10/site-packages/matplotlib/_api/__init__.py:222, in caching_module_getattr.<locals>.__getattr__(name)
#     220 if name in props:
#     221     return props[name].__get__(instance)
# --> 222 raise AttributeError(
#     223     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
win_gaus.shape
# Out:
# (1500,)

# %%
TEMP_afloat
# Out:
# <xarray.DataArray 'TEMP' ()>
# array(2847017.79282491)
