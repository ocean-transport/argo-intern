# %% [markdown]
# ## Spectral Analysis Test

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
points = 100
freq = 1
x = np.arange(points)
y = np.sin(k1*(x/points))

a1, k1 = (4, 90)
a2, k2 = (3, 4)

#plt.stem(x,y,linefmt='r')
plt.plot(x,y)
