# %% [markdown]
# ## Stat Examples

# %%
import my_stats as ms
import matplotlib as plt
import numpy as np
import scipy
import xarray as xr
import xrft

# %%
plots=[1,2,3,4]
for n in range(-4,1):
    data = ms.spectral_funct(100000, 200, n, 10*np.pi)
