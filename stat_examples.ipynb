# %% [markdown]
# ## Stat Examples

# %%
import my_stats as ms
import matplotlib as plt
import numpy as np
import scipy
import xarray as xr
import xrft

# %%
for n in range(-4,1):
    ms.spectral_funct(100000, 200, n, 10*np.pi)

# %%
ms.spectral_filtered_1(100000, 200, -2, 10*np.pi, 2000)

# %%
for n in range(1,3002,300):
    ms.spectral_filtered_2(100000,200,-2,10*np.pi,n)
